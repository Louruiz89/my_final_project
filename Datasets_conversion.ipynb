# %%
import pandas as pd

# %%
pueblos_bonitos = pd.read_csv('./data/pueblos_bonitos.csv', encoding='latin-1', sep=';')
pueblos_bonitos
# Out:
#                                      Pueblo    Provincia      Longitud
# 0                          Alcalá del Júcar     Albacete   -1,42932697  \
# 1                                   Almagro  Ciudad Real   -3,71155855
# 2                        Almonaster la Real       Huelva       -6,7872
# 3                                    Anento     Zaragoza   -1,33328459
# 4                                      Ansó       Huesca   -0,82888346
# ..                                      ...          ...           ...
# 75                                  Cascais     Portugal  -9,421922643
# 76                                   Sintra     Portugal  -9,379920057
# 77                                   Aveiro     Portugal  -8,656178422
# 78  Passadiços do Paiva (Montanhas Mágicas)     Portugal  -8,173088923
# 79                                   Oporto     Portugal  -8,626421659
#
#         Latitud    Datos de Interés
# 0    39,1932018  D.O. Pueblo Bonito
# 1   38,88984134  D.O. Pueblo Bonito
# ...

# %%
pb2 = pueblos_bonitos.replace(',','.', regex=True)
pb2
# Out:
#                                      Pueblo    Provincia      Longitud
# 0                          Alcalá del Júcar     Albacete   -1.42932697  \
# 1                                   Almagro  Ciudad Real   -3.71155855
# 2                        Almonaster la Real       Huelva       -6.7872
# 3                                    Anento     Zaragoza   -1.33328459
# 4                                      Ansó       Huesca   -0.82888346
# ..                                      ...          ...           ...
# 75                                  Cascais     Portugal  -9.421922643
# 76                                   Sintra     Portugal  -9.379920057
# 77                                   Aveiro     Portugal  -8.656178422
# 78  Passadiços do Paiva (Montanhas Mágicas)     Portugal  -8.173088923
# 79                                   Oporto     Portugal  -8.626421659
#
#         Latitud    Datos de Interés
# 0    39.1932018  D.O. Pueblo Bonito
# 1   38.88984134  D.O. Pueblo Bonito
# ...

# %%
save_pb2 = pb2.to_csv('./data/pueblos_bonitos_punto.csv', index=False)

# %%
puntos_cardinales = pd.read_csv('./data/puntos_cardinales.csv', encoding='latin-1', sep=';')
puntos_cardinales
# Out:
#                   Pueblo    Provincia      Longitud      Latitud
# 0               Albacete     Albacete   -1,85574745  38,99588053
# 1                Almansa     Albacete   -1,09414681  38,86968811
# 2                Andorra       Teruel   -0,44371856  40,97509431
# 3        Aranda de Duero       Burgos   -3,68924298  41,67155079
# 4                 Burgos       Burgos   -3,70419805  42,34113004
# 5              Calatayud     Zaragoza   -1,64472637  41,35431931
# 6            Ciudad Real  Ciudad Real   -3,93131981  38,98651781
# 7         Ciudad Rodrigo    Salamanca    -6,5341577  40,59730856
# 8                Nohales       Cuenca   -2,13152306  40,07653762
# 9                Granada      Granada   -3,60001883  37,17641932
# 10                Huelva       Huelva   -6,95040588  37,26004113
# 11                Huesca       Huesca   -0,40842276  42,14062739
# 12                  Lugo         Lugo  -7,555755439  43,00988951
# ...

# %%
pc2 = puntos_cardinales.replace(',','.', regex=True)
pc2
# Out:
#                   Pueblo    Provincia      Longitud      Latitud
# 0               Albacete     Albacete   -1.85574745  38.99588053
# 1                Almansa     Albacete   -1.09414681  38.86968811
# 2                Andorra       Teruel   -0.44371856  40.97509431
# 3        Aranda de Duero       Burgos   -3.68924298  41.67155079
# 4                 Burgos       Burgos   -3.70419805  42.34113004
# 5              Calatayud     Zaragoza   -1.64472637  41.35431931
# 6            Ciudad Real  Ciudad Real   -3.93131981  38.98651781
# 7         Ciudad Rodrigo    Salamanca    -6.5341577  40.59730856
# 8                Nohales       Cuenca   -2.13152306  40.07653762
# 9                Granada      Granada   -3.60001883  37.17641932
# 10                Huelva       Huelva   -6.95040588  37.26004113
# 11                Huesca       Huesca   -0.40842276  42.14062739
# 12                  Lugo         Lugo  -7.555755439  43.00988951
# ...

# %%
save_pc2 = pc2.to_csv('./data/puntos_cardinales_punto.csv', index=False)

# %%
test = pd.read_csv('./data/puntos_cardinales_punto.csv')
test
# Out:
#                   Pueblo    Provincia  Longitud    Latitud
# 0               Albacete     Albacete -1.855747  38.995881
# 1                Almansa     Albacete -1.094147  38.869688
# 2                Andorra       Teruel -0.443719  40.975094
# 3        Aranda de Duero       Burgos -3.689243  41.671551
# 4                 Burgos       Burgos -3.704198  42.341130
# 5              Calatayud     Zaragoza -1.644726  41.354319
# 6            Ciudad Real  Ciudad Real -3.931320  38.986518
# 7         Ciudad Rodrigo    Salamanca -6.534158  40.597309
# 8                Nohales       Cuenca -2.131523  40.076538
# 9                Granada      Granada -3.600019  37.176419
# 10                Huelva       Huelva -6.950406  37.260041
# 11                Huesca       Huesca -0.408423  42.140627
# 12                  Lugo         Lugo -7.555755  43.009890
# 13                Murcia       Murcia -1.128541  37.984364
# 14             Plasencia      Cáceres -6.092682  40.029405
# ...
